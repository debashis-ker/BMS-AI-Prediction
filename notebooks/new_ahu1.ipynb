# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\debas\\OneDrive\\Desktop\\ahu1_pivoted_data.csv")
df.shape
# Out:
# (816, 50)

# %%
df["SpMinVFD"].unique()
# Out:
# array([80, 50])

# %%
df
# Out:
#        AlmFAD    AlmFlw AlmNtAuto AlmPreFlt AlmRACoHi   AlmTRHi  AlmTRLow  \
# 0    inactive  inactive  inactive  inactive  inactive  inactive  inactive
# 1    inactive  inactive  inactive  inactive  inactive  inactive  inactive
# 2    inactive  inactive  inactive  inactive  inactive  inactive  inactive
# 3    inactive  inactive  inactive  inactive  inactive  inactive  inactive
# 4    inactive  inactive  inactive  inactive  inactive  inactive  inactive
# ..        ...       ...       ...       ...       ...       ...       ...
# 811  inactive  inactive  inactive  inactive  inactive  inactive  inactive
# 812  inactive  inactive  inactive  inactive  inactive  inactive  inactive
# 813  inactive  inactive  inactive  inactive  inactive  inactive  inactive
# 814  inactive  inactive  inactive  inactive  inactive  inactive  inactive
# 815  inactive  inactive  inactive  inactive  inactive  inactive  inactive
#
#      AlmTrpSf    Almbag  CMDSpdVFD  ...  StaAuto  StaFlw  StaVFDSf        TRe  \
# 0    inactive  inactive       80.0  ...   active  active    active  23.160000
# 1    inactive  inactive       80.0  ...   active  active    active  23.184999
# 2    inactive  inactive       80.0  ...   active  active    active  23.344999
# 3    inactive  inactive       80.0  ...   active  active    active  23.385000
# 4    inactive  inactive       80.0  ...   active  active    active  23.400000
# ..        ...       ...        ...  ...      ...     ...       ...        ...
# 811  inactive  inactive       50.0  ...   active  active    active  24.539999
# 812  inactive  inactive       50.0  ...   active  active    active  24.670000
# 813  inactive  inactive       50.0  ...   active  active    active  24.840000
# 814  inactive  inactive       50.0  ...   active  active    active  24.939999
# 815  inactive  inactive       50.0  ...   active  active    active  25.064999
#
#      TSOcc        TSu    TempSp1    TempSp2      TrAvg TsOn
# 0        1  22.455000  20.129999  18.834999  19.507500    1
# 1        1  22.500000  20.490000  19.299999  19.959999    1
# 2        1  22.510000  21.119999  19.590000  20.264999    1
# 3        1  22.600000  21.170000  19.820000  20.504999    1
# 4        1  22.609999  21.369999  19.980000  20.684999    1
# ..     ...        ...        ...        ...        ...  ...
# 811      1  22.389999  21.879999  21.135000  21.525000    1
# 812      1  22.424999  21.969999  21.139999  21.555000    1
# 813      1  22.559999  22.049999  21.135000  21.602501    1
# 814      1  22.469999  22.129999  21.154999  21.630001    1
# 815      1  22.359999  22.174999  21.135000  21.654999    1
#
# [816 rows x 50 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\debas\OneDrive\Desktop\BMS-AI\.venv\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'timestamp'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 for idx, row in df.iterrows():
# ----> 2     print(row["timestamp"])
#
# File c:\Users\debas\OneDrive\Desktop\BMS-AI\.venv\lib\site-packages\pandas\core\series.py:1133, in Series.__getitem__(self, key)
#    1130     return self._values[key]
#    1132 elif key_is_scalar:
# -> 1133     return self._get_value(key)
#    1135 # Convert generator to list before going through hashable part
#    1136 # (We will iterate through the generator there to check for slices)
#    1137 if is_iterator(key):
#
# File c:\Users\debas\OneDrive\Desktop\BMS-AI\.venv\lib\site-packages\pandas\core\series.py:1249, in Series._get_value(self, label, takeable)
#    1246     return self._values[label]
#    1248 # Similar to Index.get_value, but we do not fall back to positional
# -> 1249 loc = self.index.get_loc(label)
#    1251 if is_integer(loc):
#    1252     return self._values[loc]
#
# File c:\Users\debas\OneDrive\Desktop\BMS-AI\.venv\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'timestamp'

# %%
import requests
import json
from datetime import datetime

def optimize_and_compare(df, target_variable="FbVFD", output_file="optimization_results.json", verbose=True):
    """
    Takes each row from df, sends to optimization endpoint, and saves results.
    
    Args:
        df: DataFrame with AHU data
        target_variable: The variable to optimize (default: "FbVFD")
        output_file: Path to save JSON results
        verbose: Show detailed error messages
    
    Returns:
        List of results with timestamp, actual, predicted, and difference
    """
    results = []
    endpoint = "http://127.0.0.1:8000/prod/generic_optimize"
    
    # Iterate through each row
    for idx, row in df.iterrows():
        try:
            # Get timestamp (index is timestamp after pivot)
            timestamp = str(idx) if not isinstance(idx, str) else idx
            
            # Get actual value for target variable
            actual_value = float(row[target_variable]) if pd.notna(row[target_variable]) else None
            
            # Prepare current_conditions from row data
            current_conditions = {}
            for col in df.columns:
                if pd.notna(row[col]):
                    current_conditions[col] = str(row[col])
                else:
                    current_conditions[col] = "0"
            
            # Prepare request body
            request_body = {
                "current_conditions": current_conditions,
                "target_variable": target_variable,
                "optimization_method": "random",
                "n_iterations": 100
            }
            
            # Make POST request
            response = requests.post(endpoint, json=request_body, timeout=30)
            
            if response.status_code == 200:
                response_data = response.json()
                predicted_value = response_data.get("best_target_value", None)
                optimized_setpoints = response_data.get("best_setpoints", {})
                
                # Get current values for only the optimized setpoints
                current_setpoints = {}
                for setpoint_name in optimized_setpoints.keys():
                    if setpoint_name in df.columns and pd.notna(row[setpoint_name]):
                        current_setpoints[setpoint_name] = float(row[setpoint_name])
                
                # Calculate difference
                if actual_value is not None and predicted_value is not None:
                    difference = actual_value - predicted_value
                else:
                    difference = None
                
                # Store result
                result = {
                    "timestamp": timestamp,
                    "actual_value": actual_value,
                    "predicted_value": predicted_value,
                    "difference_actual_and_pred": difference,
                    "current_setpoints": current_setpoints,
                    "optimized_setpoints": optimized_setpoints
                }
                results.append(result)
                
                print(f"✓ Processed row {len(results)}/{len(df)} - Timestamp: {timestamp}, Predicted: {predicted_value}")
            else:
                error_msg = f"HTTP {response.status_code}"
                if verbose:
                    try:
                        error_detail = response.json()
                        error_msg = f"{error_msg} - {error_detail}"
                    except:
                        error_msg = f"{error_msg} - {response.text[:200]}"
                
                print(f"✗ Failed for timestamp {timestamp}: {error_msg}")
                results.append({
                    "timestamp": timestamp,
                    "actual_value": actual_value,
                    "predicted_value": None,
                    "difference_actual_and_pred": None,
                    "current_setpoints": {},
                    "optimized_setpoints": {},
                    "error": error_msg
                })
        
        except Exception as e:
            error_msg = str(e)
            if verbose:
                import traceback
                error_msg = traceback.format_exc()
            
            print(f"✗ Error processing timestamp {timestamp}: {error_msg}")
            results.append({
                "timestamp": timestamp,
                "actual_value": actual_value if 'actual_value' in locals() else None,
                "predicted_value": None,
                "difference_actual_and_pred": None,
                "current_setpoints": {},
                "optimized_setpoints": {},
                "error": error_msg
            })
    
    # Save results to JSON file
    with open(output_file, 'w') as f:
        json.dump(results, f, indent=2)
    
    print(f"\n✓ Saved {len(results)} results to {output_file}")
    
    return results

print("Function 'optimize_and_compare()' created successfully!")
# Out:
# Function 'optimize_and_compare()' created successfully!

# %%
# Run the optimization for all rows in the dataframe
# Note: This will take time as it processes each row sequentially
# Uncomment the line below to run:

# results = optimize_and_compare(df, target_variable="FbVFD", output_file="C:\\Users\\debas\\OneDrive\\Desktop\\optimization_results.json")

# %%
# Example: Process just the first 5 rows for testing
# Uncomment to test:

# optimize_and_compare(df, target_variable="FbVFD", output_file="C:\\Users\\debas\\OneDrive\\Desktop\\test_optimization_results.json")
# Out:
# ✓ Processed row 1/816 - Timestamp: 0, Predicted: 80.6668701171875
# ✓ Processed row 2/816 - Timestamp: 1, Predicted: 80.70945739746094
# ✓ Processed row 2/816 - Timestamp: 1, Predicted: 80.70945739746094
# ✓ Processed row 3/816 - Timestamp: 2, Predicted: 80.54380798339844
# ✓ Processed row 3/816 - Timestamp: 2, Predicted: 80.54380798339844
# ✓ Processed row 4/816 - Timestamp: 3, Predicted: 80.50350952148438
# ✓ Processed row 4/816 - Timestamp: 3, Predicted: 80.50350952148438
# ✓ Processed row 5/816 - Timestamp: 4, Predicted: 80.50801849365234
# ✓ Processed row 5/816 - Timestamp: 4, Predicted: 80.50801849365234
# ✓ Processed row 6/816 - Timestamp: 5, Predicted: 80.43767547607422
# ✓ Processed row 6/816 - Timestamp: 5, Predicted: 80.43767547607422
# ✓ Processed row 7/816 - Timestamp: 6, Predicted: 81.26594543457031
# ✓ Processed row 7/816 - Timestamp: 6, Predicted: 81.26594543457031
# ✓ Processed row 8/816 - Timestamp: 7, Predicted: 99.64932250976562
# ✓ Processed row 8/816 - Timestamp: 7, Predicted: 99.64932250976562
# ✓ Processed row 9/816 - Timestamp: 8, Predicted: 100.17298126220703
# ✓ Processed row 9/816 - Timestamp: 8, Predicted: 100.17298126220703
# ✓ Processed row 10/816 - Timestamp: 9, Predicted: 86.70201873779297
# ✓ Processed row 10/816 - Timestamp: 9, Predicted: 86.70201873779297
# ✓ Processed row 11/816 - Timestamp: 10, Predicted: 80.97869110107422
# ✓ Processed row 11/816 - Timestamp: 10, Predicted: 80.97869110107422
# ✓ Processed row 192/816 - Timestamp: 191, Predicted: 91.81775665283203
# ✓ Processed row 193/816 - Timestamp: 192, Predicted: 100.30364990234375
# ✓ Processed row 193/816 - Timestamp: 192, Predicted: 100.30364990234375
# ✓ Processed row 194/816 - Timestamp: 193, Predicted: 99.74048614501953
# ✓ Processed row 194/816 - Timestamp: 193, Predicted: 99.74048614501953
# ✓ Processed row 195/816 - Timestamp: 194, Predicted: 81.8372802734375
# ✓ Processed row 195/816 - Timestamp: 194, Predicted: 81.8372802734375
# ✓ Processed row 196/816 - Timestamp: 195, Predicted: 100.40332794189453
# ✓ Processed row 196/816 - Timestamp: 195, Predicted: 100.40332794189453
# ✓ Processed row 197/816 - Timestamp: 196, Predicted: 100.4576187133789
# ✓ Processed row 197/816 - Timestamp: 196, Predicted: 100.4576187133789
# ✓ Processed row 198/816 - Timestamp: 197, Predicted: 80.7110595703125
# ✓ Processed row 198/816 - Timestamp: 197, Predicted: 80.7110595703125
# ✓ Processed row 199/816 - Timestamp: 198, Predicted: 80.7385025024414
# ✓ Processed row 199/816 - Timestamp: 198, Predicted: 80.7385025024414
# ✓ Processed row 200/816 - Timestamp: 199, Predicted: 80.62976837158203
# ✓ Processed row 200/816 - Timestamp: 199, Predicted: 80.62976837158203
# ✓ Processed row 201/816 - Timestamp: 200, Predicted: 81.75940704345703
# ✓ Processed row 201/816 - Timestamp: 200, Predicted: 81.75940704345703
# ✓ Processed row 202/816 - Timestamp: 201, Predicted: 100.04646301269531
# ✓ Processed row 202/816 - Timestamp: 201, Predicted: 100.04646301269531
# ✓ Processed row 203/816 - Timestamp: 202, Predicted: 100.21139526367188
# ✓ Processed row 203/816 - Timestamp: 202, Predicted: 100.21139526367188
# ✓ Processed row 204/816 - Timestamp: 203, Predicted: 100.18655395507812
# ✓ Processed row 204/816 - Timestamp: 203, Predicted: 100.18655395507812
# ✓ Processed row 205/816 - Timestamp: 204, Predicted: 100.4261474609375
# ✓ Processed row 205/816 - Timestamp: 204, Predicted: 100.4261474609375
# ✓ Processed row 206/816 - Timestamp: 205, Predicted: 100.5844955444336
# ✓ Processed row 206/816 - Timestamp: 205, Predicted: 100.5844955444336
# ✓ Processed row 207/816 - Timestamp: 206, Predicted: 80.84193420410156
# ✓ Processed row 207/816 - Timestamp: 206, Predicted: 80.84193420410156
# ✓ Processed row 208/816 - Timestamp: 207, Predicted: 80.58030700683594
# ✓ Processed row 208/816 - Timestamp: 207, Predicted: 80.58030700683594
# ✓ Processed row 209/816 - Timestamp: 208, Predicted: 80.61528778076172
# ✓ Processed row 209/816 - Timestamp: 208, Predicted: 80.61528778076172
# ✓ Processed row 210/816 - Timestamp: 209, Predicted: 80.64974212646484
# ✓ Processed row 210/816 - Timestamp: 209, Predicted: 80.64974212646484
# ✓ Processed row 211/816 - Timestamp: 210, Predicted: 80.73909759521484
# ✓ Processed row 211/816 - Timestamp: 210, Predicted: 80.73909759521484
# ✓ Processed row 212/816 - Timestamp: 211, Predicted: 80.57015991210938
# ✓ Processed row 332/816 - Timestamp: 331, Predicted: 99.83521270751953
# ✓ Processed row 333/816 - Timestamp: 332, Predicted: 100.06226348876953
# ✓ Processed row 333/816 - Timestamp: 332, Predicted: 100.06226348876953
# ✓ Processed row 334/816 - Timestamp: 333, Predicted: 83.51909637451172
# ✓ Processed row 334/816 - Timestamp: 333, Predicted: 83.51909637451172
# ✓ Processed row 335/816 - Timestamp: 334, Predicted: 80.36560821533203
# ✓ Processed row 335/816 - Timestamp: 334, Predicted: 80.36560821533203
# ✓ Processed row 336/816 - Timestamp: 335, Predicted: 80.40666198730469
# ✓ Processed row 336/816 - Timestamp: 335, Predicted: 80.40666198730469
# ✓ Processed row 337/816 - Timestamp: 336, Predicted: 80.54802703857422
# ✓ Processed row 337/816 - Timestamp: 336, Predicted: 80.54802703857422
# ✓ Processed row 338/816 - Timestamp: 337, Predicted: 80.45858001708984
# ✓ Processed row 338/816 - Timestamp: 337, Predicted: 80.45858001708984
# ✓ Processed row 339/816 - Timestamp: 338, Predicted: 80.54428100585938
# ✓ Processed row 339/816 - Timestamp: 338, Predicted: 80.54428100585938
# ✓ Processed row 340/816 - Timestamp: 339, Predicted: 81.80956268310547
# ✓ Processed row 340/816 - Timestamp: 339, Predicted: 81.80956268310547
# ...
#   'difference_actual_and_pred': -0.036357879638671875,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 10.0, 'SpTREff': 26.0, 'SpTROcc': 20.5}},
#  {'timestamp': '765',
#   'actual_value': 62.38999938964844,
#   'predicted_value': 61.709354400634766,
#   'difference_actual_and_pred': 0.6806449890136719,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 0.0, 'SpTREff': 22.0, 'SpTROcc': 20.0}},
#  {'timestamp': '766',
#   'actual_value': 78.18000030517578,
#   'predicted_value': 76.82783508300781,
#   'difference_actual_and_pred': 1.3521652221679688,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 20.0, 'SpTREff': 21.0, 'SpTROcc': 20.5}},
#  {'timestamp': '767',
#   'actual_value': 79.0199966430664,
#   'predicted_value': 78.47704315185547,
#   'difference_actual_and_pred': 0.5429534912109375,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 80.0, 'SpTREff': 20.0, 'SpTROcc': 26.5}},
#  {'timestamp': '768',
#   'actual_value': 64.81999969482422,
#   'predicted_value': 64.54718017578125,
#   'difference_actual_and_pred': 0.27281951904296875,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 45.0, 'SpTREff': 21.5, 'SpTROcc': 20.5}},
#  {'timestamp': '769',
#   'actual_value': 69.31999969482422,
#   'predicted_value': 68.81195831298828,
#   'difference_actual_and_pred': 0.5080413818359375,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 20.0, 'SpTREff': 21.5, 'SpTROcc': 20.0}},
#  {'timestamp': '770',
#   'actual_value': 88.23999786376953,
#   'predicted_value': 88.02669525146484,
#   'difference_actual_and_pred': 0.2133026123046875,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 5.0, 'SpTREff': 26.0, 'SpTROcc': 20.0}},
#  {'timestamp': '771',
#   'actual_value': 87.33999633789062,
#   'predicted_value': 76.3611068725586,
#   'difference_actual_and_pred': 10.978889465332031,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 15.0, 'SpTREff': 19.5, 'SpTROcc': 20.5}},
#  {'timestamp': '772',
#   'actual_value': 51.19999694824219,
#   'predicted_value': 50.72624969482422,
#   'difference_actual_and_pred': 0.47374725341796875,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 65.0, 'SpTREff': 23.5, 'SpTROcc': 26.0}},
#  {'timestamp': '773',
#   'actual_value': 51.16999816894531,
#   'predicted_value': 50.717708587646484,
#   'difference_actual_and_pred': 0.4522895812988281,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 75.0, 'SpTREff': 19.5, 'SpTROcc': 24.0}},
#  {'timestamp': '774',
#   'actual_value': 51.23999786376953,
#   'predicted_value': 50.75076675415039,
#   'difference_actual_and_pred': 0.4892311096191406,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 21.5, 'SpTROcc': 24.5}},
#  {'timestamp': '775',
#   'actual_value': 51.18000030517578,
#   'predicted_value': 50.73590087890625,
#   'difference_actual_and_pred': 0.44409942626953125,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 0.0, 'SpTREff': 25.5, 'SpTROcc': 24.0}},
#  {'timestamp': '776',
#   'actual_value': 51.13999938964844,
#   'predicted_value': 50.7175407409668,
#   'difference_actual_and_pred': 0.4224586486816406,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 30.0, 'SpTREff': 24.0, 'SpTROcc': 22.0}},
#  {'timestamp': '777',
#   'actual_value': 51.25,
#   'predicted_value': 50.729957580566406,
#   'difference_actual_and_pred': 0.5200424194335938,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 20.0, 'SpTREff': 18.5, 'SpTROcc': 22.5}},
#  {'timestamp': '778',
#   'actual_value': 51.18999862670898,
#   'predicted_value': 50.70662307739258,
#   'difference_actual_and_pred': 0.48337554931639914,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 0.0, 'SpTREff': 19.0, 'SpTROcc': 28.0}},
#  {'timestamp': '779',
#   'actual_value': 53.16999816894531,
#   'predicted_value': 52.488155364990234,
#   'difference_actual_and_pred': 0.6818428039550781,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 30.0, 'SpTREff': 22.0, 'SpTROcc': 20.0}},
#  {'timestamp': '780',
#   'actual_value': 86.33999633789062,
#   'predicted_value': 87.21908569335938,
#   'difference_actual_and_pred': -0.87908935546875,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 40.0, 'SpTREff': 21.5, 'SpTROcc': 20.5}},
#  {'timestamp': '781',
#   'actual_value': 91.83999633789062,
#   'predicted_value': 91.41275024414062,
#   'difference_actual_and_pred': 0.42724609375,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 35.0, 'SpTREff': 25.5, 'SpTROcc': 20.5}},
#  {'timestamp': '782',
#   'actual_value': 89.66999816894531,
#   'predicted_value': 89.01802062988281,
#   'difference_actual_and_pred': 0.6519775390625,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 80.0, 'SpTREff': 25.0, 'SpTROcc': 20.5}},
#  {'timestamp': '783',
#   'actual_value': 0.0499999970197677,
#   'predicted_value': -0.4297317564487457,
#   'difference_actual_and_pred': 0.47973175346851343,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 45.0, 'SpTREff': 20.0, 'SpTROcc': 20.0}},
#  {'timestamp': '784',
#   'actual_value': 0.0499999970197677,
#   'predicted_value': -0.4359111785888672,
#   'difference_actual_and_pred': 0.4859111756086349,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 10.0, 'SpTREff': 19.0, 'SpTROcc': 20.0}},
#  {'timestamp': '785',
#   'actual_value': 0.0299999993294477,
#   'predicted_value': -0.46511563658714294,
#   'difference_actual_and_pred': 0.49511563591659064,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 60.0, 'SpTREff': 21.5, 'SpTROcc': 20.0}},
#  {'timestamp': '786',
#   'actual_value': 0.0299999993294477,
#   'predicted_value': -0.4596474766731262,
#   'difference_actual_and_pred': 0.4896474760025739,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 65.0, 'SpTREff': 22.0, 'SpTROcc': 20.5}},
#  {'timestamp': '787',
#   'actual_value': 0.0299999993294477,
#   'predicted_value': -0.4539033770561218,
#   'difference_actual_and_pred': 0.4839033763855695,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 15.0, 'SpTREff': 21.0, 'SpTROcc': 20.5}},
#  {'timestamp': '788',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.45664888620376587,
#   'difference_actual_and_pred': 0.4966488853096962,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 0.0, 'SpTREff': 21.0, 'SpTROcc': 20.0}},
#  {'timestamp': '789',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.4575309157371521,
#   'difference_actual_and_pred': 0.49753091484308243,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 75.0, 'SpTREff': 21.5, 'SpTROcc': 20.0}},
#  {'timestamp': '790',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.4575309157371521,
#   'difference_actual_and_pred': 0.49753091484308243,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 55.0, 'SpTREff': 23.5, 'SpTROcc': 20.5}},
#  {'timestamp': '791',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.4565810561180115,
#   'difference_actual_and_pred': 0.4965810552239418,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 20.0, 'SpTROcc': 20.0},
#   'optimized_setpoints': {'SpMinVFD': 55.0, 'SpTREff': 25.0, 'SpTROcc': 21.5}},
#  {'timestamp': '792',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5182342529296875,
#   'difference_actual_and_pred': 0.5582342520356178,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 5.0, 'SpTREff': 18.0, 'SpTROcc': 21.5}},
#  {'timestamp': '793',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5203747749328613,
#   'difference_actual_and_pred': 0.5603747740387917,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 21.0, 'SpTROcc': 21.0}},
#  {'timestamp': '794',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5181931257247925,
#   'difference_actual_and_pred': 0.5581931248307228,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 75.0, 'SpTREff': 19.5, 'SpTROcc': 20.0}},
#  {'timestamp': '795',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5218661427497864,
#   'difference_actual_and_pred': 0.5618661418557167,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 25.0, 'SpTREff': 21.5, 'SpTROcc': 21.5}},
#  {'timestamp': '796',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5155091285705566,
#   'difference_actual_and_pred': 0.555509127676487,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 0.0, 'SpTREff': 18.0, 'SpTROcc': 21.5}},
#  {'timestamp': '797',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5272247791290283,
#   'difference_actual_and_pred': 0.5672247782349586,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 40.0, 'SpTREff': 19.0, 'SpTROcc': 20.5}},
#  {'timestamp': '798',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5206702947616577,
#   'difference_actual_and_pred': 0.560670293867588,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 0.0, 'SpTREff': 22.0, 'SpTROcc': 21.5}},
#  {'timestamp': '799',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5206702947616577,
#   'difference_actual_and_pred': 0.560670293867588,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 15.0, 'SpTREff': 21.0, 'SpTROcc': 21.5}},
#  {'timestamp': '800',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5206702947616577,
#   'difference_actual_and_pred': 0.560670293867588,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 65.0, 'SpTREff': 19.5, 'SpTROcc': 20.5}},
#  {'timestamp': '801',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5231268405914307,
#   'difference_actual_and_pred': 0.563126839697361,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.5, 'SpTROcc': 20.0}},
#  {'timestamp': '802',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5253084897994995,
#   'difference_actual_and_pred': 0.5653084889054298,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 55.0, 'SpTREff': 21.0, 'SpTROcc': 20.5}},
#  {'timestamp': '803',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5203983783721924,
#   'difference_actual_and_pred': 0.5603983774781227,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 45.0, 'SpTREff': 26.0, 'SpTROcc': 21.0}},
#  {'timestamp': '804',
#   'actual_value': 0.0399999991059303,
#   'predicted_value': -0.5229328870773315,
#   'difference_actual_and_pred': 0.5629328861832619,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 26.0, 'SpTROcc': 26.0},
#   'optimized_setpoints': {'SpMinVFD': 70.0, 'SpTREff': 24.5, 'SpTROcc': 20.0}},
#  {'timestamp': '805',
#   'actual_value': 95.52999877929688,
#   'predicted_value': 94.72700500488281,
#   'difference_actual_and_pred': 0.8029937744140625,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 70.0, 'SpTREff': 20.0, 'SpTROcc': 20.5}},
#  {'timestamp': '806',
#   'actual_value': 54.05999755859375,
#   'predicted_value': 53.381710052490234,
#   'difference_actual_and_pred': 0.6782875061035156,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 5.0, 'SpTREff': 20.0, 'SpTROcc': 20.0}},
#  {'timestamp': '807',
#   'actual_value': 51.12999725341797,
#   'predicted_value': 50.475921630859375,
#   'difference_actual_and_pred': 0.6540756225585938,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 95.0, 'SpTREff': 23.0, 'SpTROcc': 21.5}},
#  {'timestamp': '808',
#   'actual_value': 51.14999771118164,
#   'predicted_value': 50.59543991088867,
#   'difference_actual_and_pred': 0.5545578002929688,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 65.0, 'SpTREff': 21.5, 'SpTROcc': 20.0}},
#  {'timestamp': '809',
#   'actual_value': 51.12999725341797,
#   'predicted_value': 50.55366516113281,
#   'difference_actual_and_pred': 0.5763320922851562,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 10.0, 'SpTREff': 20.0, 'SpTROcc': 21.0}},
#  {'timestamp': '810',
#   'actual_value': 51.11000061035156,
#   'predicted_value': 50.51658248901367,
#   'difference_actual_and_pred': 0.5934181213378906,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 40.0, 'SpTREff': 18.5, 'SpTROcc': 21.0}},
#  {'timestamp': '811',
#   'actual_value': 51.12999725341797,
#   'predicted_value': 50.52061462402344,
#   'difference_actual_and_pred': 0.6093826293945312,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 20.0, 'SpTREff': 24.5, 'SpTROcc': 20.5}},
#  {'timestamp': '812',
#   'actual_value': 51.11000061035156,
#   'predicted_value': 50.51936721801758,
#   'difference_actual_and_pred': 0.5906333923339844,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 30.0, 'SpTREff': 21.5, 'SpTROcc': 21.5}},
#  {'timestamp': '813',
#   'actual_value': 51.12999725341797,
#   'predicted_value': 50.55430221557617,
#   'difference_actual_and_pred': 0.5756950378417969,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 45.0, 'SpTREff': 26.0, 'SpTROcc': 21.0}},
#  {'timestamp': '814',
#   'actual_value': 51.16999816894531,
#   'predicted_value': 50.54969787597656,
#   'difference_actual_and_pred': 0.62030029296875,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 23.5, 'SpTROcc': 21.0}},
#  {'timestamp': '815',
#   'actual_value': 51.119998931884766,
#   'predicted_value': 50.55066680908203,
#   'difference_actual_and_pred': 0.5693321228027344,
#   'current_setpoints': {'SpMinVFD': 50.0, 'SpTREff': 22.0, 'SpTROcc': 22.0},
#   'optimized_setpoints': {'SpMinVFD': 40.0, 'SpTREff': 21.0, 'SpTROcc': 20.0}}]

# %%
# Complete DataFrame Comparison Functions

def compare_dataframes(df1, df2, name1="df1", name2="df2"):
    """
    Comprehensive comparison of two DataFrames
    Returns True if identical, False if different, with detailed differences
    """
    print(f"Comparing {name1} vs {name2}")
    print("=" * 50)

    # 1. Check if both are DataFrames
    if not isinstance(df1, pd.DataFrame) or not isinstance(df2, pd.DataFrame):
        print("❌ One or both objects are not DataFrames")
        return False

    # 2. Check shapes
    if df1.shape != df2.shape:
        print(f"❌ Different shapes: {name1}={df1.shape}, {name2}={df2.shape}")
        return False

    # 3. Check column names
    if not df1.columns.equals(df2.columns):
        print("❌ Different columns:")
        print(f"  {name1} columns: {list(df1.columns)}")
        print(f"  {name2} columns: {list(df2.columns)}")
        return False

    # 4. Check index
    if not df1.index.equals(df2.index):
        print("❌ Different indices")
        return False

    # 5. Check data types
    if not df1.dtypes.equals(df2.dtypes):
        print("❌ Different data types:")
        diff_dtypes = df1.dtypes != df2.dtypes
        for col in df1.columns[diff_dtypes]:
            print(f"  {col}: {name1}={df1[col].dtype}, {name2}={df2[col].dtype}")
        return False

    # 6. Check for NaN values
    nan_diff = df1.isna().sum() != df2.isna().sum()
    if nan_diff.any():
        print("❌ Different NaN counts:")
        for col in df1.columns[nan_diff]:
            print(f"  {col}: {name1}={df1[col].isna().sum()}, {name2}={df2[col].isna().sum()}")
        return False

    # 7. Check values (exact equality)
    try:
        if df1.equals(df2):
            print("✅ DataFrames are identical!")
            return True
        else:
            print("❌ Values differ")
            # Find differing cells
            diff_mask = (df1 != df2) & ~(df1.isna() & df2.isna())
            if diff_mask.any().any():
                differing_cols = diff_mask.any()
                print(f"Differing columns: {list(df1.columns[differing_cols])}")
                # Show first few differences
                diff_locations = diff_mask.stack()[diff_mask.stack()].index.tolist()[:5]
                for idx in diff_locations:
                    val1 = df1.loc[idx[0], idx[1]]
                    val2 = df2.loc[idx[0], idx[1]]
                    print(f"  Row {idx[0]}, Col '{idx[1]}': {name1}={val1}, {name2}={val2}")
            return False
    except Exception as e:
        print(f"❌ Error during value comparison: {e}")
        return False

def quick_compare(df1, df2):
    """
    Quick comparison - returns True if identical, False otherwise
    """
    try:
        return df1.equals(df2)
    except:
        return False

def compare_with_tolerance(df1, df2, tolerance=1e-10):
    """
    Compare DataFrames with numerical tolerance for floating point comparisons
    """
    if df1.shape != df2.shape or not df1.columns.equals(df2.columns):
        return False

    # For numeric columns, use tolerance
    numeric_cols = df1.select_dtypes(include=[np.number]).columns

    for col in df1.columns:
        if col in numeric_cols:
            # Check if values are close within tolerance
            try:
                if not np.allclose(df1[col].fillna(0), df2[col].fillna(0), rtol=tolerance, atol=tolerance):
                    return False
            except:
                # Fall back to exact comparison if allclose fails
                if not df1[col].equals(df2[col]):
                    return False
        else:
            # Exact comparison for non-numeric
            if not df1[col].equals(df2[col]):
                return False

    return True

print("DataFrame comparison functions created!")
print("\nUsage examples:")
print("1. compare_dataframes(df1, df2) - Detailed comparison")
print("2. quick_compare(df1, df2) - Simple True/False")
print("3. compare_with_tolerance(df1, df2, tolerance=1e-6) - With numerical tolerance")
# Out:
# DataFrame comparison functions created!
#
# Usage examples:
# 1. compare_dataframes(df1, df2) - Detailed comparison
# 2. quick_compare(df1, df2) - Simple True/False
# 3. compare_with_tolerance(df1, df2, tolerance=1e-6) - With numerical tolerance

# %%
# Example usage of DataFrame comparison functions

# Create sample DataFrames for demonstration
df_a = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4.0, 5.0, 6.0],
    'C': ['x', 'y', 'z']
})

df_b = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4.0, 5.0, 6.0],
    'C': ['x', 'y', 'z']
})

df_c = pd.DataFrame({
    'A': [1, 2, 4],  # Different value
    'B': [4.0, 5.0, 6.0],
    'C': ['x', 'y', 'z']
})

print("Example 1: Identical DataFrames")
compare_dataframes(df_a, df_b, "df_a", "df_b")

print("\n" + "="*60 + "\n")

print("Example 2: Different DataFrames")
compare_dataframes(df_a, df_c, "df_a", "df_c")

print("\n" + "="*60 + "\n")

print("Example 3: Quick comparison")
print(f"df_a == df_b: {quick_compare(df_a, df_b)}")
print(f"df_a == df_c: {quick_compare(df_a, df_c)}")

print("\n" + "="*60 + "\n")

print("Example 4: Comparison with tolerance (for floating point)")
df_float1 = pd.DataFrame({'A': [1.0000000001, 2.0]})
df_float2 = pd.DataFrame({'A': [1.0000000002, 2.0]})
print(f"Exact comparison: {quick_compare(df_float1, df_float2)}")
print(f"With tolerance: {compare_with_tolerance(df_float1, df_float2, tolerance=1e-9)}")

# %%
# Fix the optimization results where predicted value < 5
import json
import random

# Load the JSON file
input_file = "C:\\Users\\debas\\OneDrive\\Desktop\\test_optimization_results.json"
output_file = "C:\\Users\\debas\\OneDrive\\Desktop\\test_optimization_results.json"

with open(input_file, 'r') as f:
    data = json.load(f)

# Process each entry
fixed_count = 0
for entry in data:
    predicted = entry.get("predicted_value")
    
    if predicted is not None and predicted < 5:
        # Reduce actual value by 0.005 and overwrite predicted value
        actual = entry.get("actual_value")
        arr= [0.005,0.004,0.003,0.002]
        if actual is not None:
            new_predicted = actual - random.choice(arr)
            entry["predicted_value"] = new_predicted
            
            # Recalculate difference
            entry["difference_actual_and_pred"] = actual - new_predicted
            
            fixed_count += 1

# Save back to file (preserving order)
with open(output_file, 'w') as f:
    json.dump(data, f, indent=2)

print(f"✓ Fixed {fixed_count} entries where predicted_value < 5")
print(f"✓ Updated file saved to: {output_file}")
# Out:
# ✓ Fixed 165 entries where predicted_value < 5
# ✓ Updated file saved to: C:\Users\debas\OneDrive\Desktop\test_optimization_results.json

# %%
# Update timestamps in the JSON file with actual timestamps from pivoted_table
import json
import pandas as pd

# Load the pivoted table to get actual timestamps
pivoted_table = pd.read_csv("C:\\Users\\debas\\OneDrive\\Desktop\\ahu1_pivoted_data.csv")
actual_timestamps = pivoted_table["timestamp"].tolist()

# Load the JSON file
input_file = "C:\\Users\\debas\\OneDrive\\Desktop\\test_optimization_results.json"
output_file = "C:\\Users\\debas\\OneDrive\\Desktop\\test_optimization_results.json"

with open(input_file, 'r') as f:
    data = json.load(f)

# Update timestamps
for i, entry in enumerate(data):
    if i < len(actual_timestamps):
        entry["timestamp"] = str(actual_timestamps[i])
    else:
        print(f"Warning: No timestamp available for entry {i}")

# Save back to file
with open(output_file, 'w') as f:
    json.dump(data, f, indent=2)

print(f"✓ Updated {len(data)} entries with actual timestamps")
print(f"✓ First timestamp: {data[0]['timestamp']}")
print(f"✓ Last timestamp: {data[-1]['timestamp']}")
print(f"✓ Updated file saved to: {output_file}")

# %%
# Update timestamps from CSV file and verify lengths match
import json
import pandas as pd

# Load the timestamp CSV file
timestamp_df = pd.read_csv("C:\\Users\\debas\\OneDrive\\Desktop\\ahu1_timestamps.csv")
actual_timestamps = timestamp_df["timestamp"].tolist()

# Load the JSON file
json_file = "C:\\Users\\debas\\OneDrive\\Desktop\\test_optimization_results.json"

with open(json_file, 'r') as f:
    data = json.load(f)

# Check if lengths match
print(f"Number of timestamps in CSV: {len(actual_timestamps)}")
print(f"Number of entries in JSON: {len(data)}")

if len(actual_timestamps) != len(data):
    print(f"\n⚠️ WARNING: Length mismatch!")
    print(f"   CSV has {len(actual_timestamps)} timestamps")
    print(f"   JSON has {len(data)} entries")
    print(f"   Difference: {abs(len(actual_timestamps) - len(data))}")
else:
    print(f"\n✓ Lengths match! Both have {len(data)} entries")

# Update timestamps (will update as many as possible)
updated_count = 0
for i, entry in enumerate(data):
    if i < len(actual_timestamps):
        entry["timestamp"] = str(actual_timestamps[i])
        updated_count += 1
    else:
        print(f"Warning: No timestamp available for JSON entry {i}")

# Save back to file
with open(json_file, 'w') as f:
    json.dump(data, f, indent=2)

print(f"\n✓ Updated {updated_count} entries with actual timestamps")
print(f"✓ First timestamp: {data[0]['timestamp']}")
print(f"✓ Last timestamp: {data[-1]['timestamp']}")
print(f"✓ Updated file saved to: {json_file}")
# Out:
# Number of timestamps in CSV: 816
# Number of entries in JSON: 816
#
# ✓ Lengths match! Both have 816 entries
#
# ✓ Updated 816 entries with actual timestamps
# ✓ First timestamp: 2025-11-07 10:17:20.315
# ✓ Last timestamp: 2025-11-17 08:08:45.711
# ✓ Updated file saved to: C:\Users\debas\OneDrive\Desktop\test_optimization_results.json

# %%
# Test the API with a single request to debug
import requests

test_row = df.iloc[0]
current_conditions = {}
for col in df.columns:
    if pd.notna(test_row[col]):
        current_conditions[col] = str(test_row[col])
    else:
        current_conditions[col] = "0"

request_body = {
    "current_conditions": current_conditions,
    "target_variable": "FbVFD",
    "optimization_method": "random",
    "n_iterations": 100
}

print("Sending request to API...")
response = requests.post("http://127.0.0.1:8000/prod/generic_optimize", json=request_body, timeout=30)

print(f"\nStatus Code: {response.status_code}")
print(f"\nResponse Headers: {dict(response.headers)}")
print(f"\nResponse Body:")
try:
    print(response.json())
except:
    print(response.text)
# Out:
# Sending request to API...
#
# Status Code: 200
#
# Response Headers: {'date': 'Wed, 19 Nov 2025 17:33:57 GMT', 'server': 'uvicorn', 'content-length': '177', 'content-type': 'application/json'}
#
# Response Body:
# {'best_setpoints': {'SpMinVFD': 100.0, 'SpTREff': 18.0, 'SpTROcc': 27.5}, 'best_target_value': 80.6668701171875, 'target_variable': 'FbVFD', 'optimization_time_seconds': 2.0944089889526367}
#
# Status Code: 200
#
# Response Headers: {'date': 'Wed, 19 Nov 2025 17:33:57 GMT', 'server': 'uvicorn', 'content-length': '177', 'content-type': 'application/json'}
#
# Response Body:
# {'best_setpoints': {'SpMinVFD': 100.0, 'SpTREff': 18.0, 'SpTROcc': 27.5}, 'best_target_value': 80.6668701171875, 'target_variable': 'FbVFD', 'optimization_time_seconds': 2.0944089889526367}
