# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv("C:\\Users\\debas\\OneDrive\\Desktop\\bacnet_latest_data.csv")

# %%
df['data_received_on'] = pd.to_datetime(df['data_received_on'], errors='coerce')

if df['data_received_on'].dt.tz is not None:
    df['timestamp'] = df['data_received_on'].dt.tz_localize(None)
else:
    df['timestamp'] = df['data_received_on']
    
    
df.set_index('timestamp', inplace=True)

# %%
ahu_df = df[df["system_type"]=="AHU"]
ahu_df.shape
# Out:
# (2179853, 15)

# %%
ahu_df
# Out:
#                                   service_id   asset_code  site system_type  \
# timestamp
# 2025-12-01 12:01:17.625  OS02-AHU-15TBCMDVFD  OS02-AHU-15  OS02         AHU
# 2025-12-01 11:19:06.756  OS02-AHU-15TBCMDVFD  OS02-AHU-15  OS02         AHU
# 2025-12-01 10:37:16.069  OS02-AHU-15TBCMDVFD  OS02-AHU-15  OS02         AHU
# 2025-12-01 09:55:09.568  OS02-AHU-15TBCMDVFD  OS02-AHU-15  OS02         AHU
# 2025-12-01 09:13:17.424  OS02-AHU-15TBCMDVFD  OS02-AHU-15  OS02         AHU
# ...                                      ...          ...   ...         ...
# 2025-11-07 08:44:33.861    OS02-AHU-15TempSu  OS02-AHU-15  OS02         AHU
# 2025-11-07 08:26:43.392    OS02-AHU-15TempSu  OS02-AHU-15  OS02         AHU
# 2025-11-07 08:11:01.973    OS02-AHU-15TempSu  OS02-AHU-15  OS02         AHU
# 2025-11-07 07:55:07.331    OS02-AHU-15TempSu  OS02-AHU-15  OS02         AHU
# 2025-11-07 07:39:03.447    OS02-AHU-15TempSu  OS02-AHU-15  OS02         AHU
#
#                          device_id device_ip                  object_name  \
# timestamp
# 2025-12-01 12:01:17.625    2122754  1:0x0102  VOX'OS02'Ahu'Ahu15'TBCMDVFD
# 2025-12-01 11:19:06.756    2122754  1:0x0102  VOX'OS02'Ahu'Ahu15'TBCMDVFD
# 2025-12-01 10:37:16.069    2122754  1:0x0102  VOX'OS02'Ahu'Ahu15'TBCMDVFD
# 2025-12-01 09:55:09.568    2122754  1:0x0102  VOX'OS02'Ahu'Ahu15'TBCMDVFD
# 2025-12-01 09:13:17.424    2122754  1:0x0102  VOX'OS02'Ahu'Ahu15'TBCMDVFD
# ...                            ...       ...                          ...
# 2025-11-07 08:44:33.861    2122754  1:0x0102    VOX'OS02'Ahu'Ahu15'TempSu
# 2025-11-07 08:26:43.392    2122754  1:0x0102    VOX'OS02'Ahu'Ahu15'TempSu
# 2025-11-07 08:11:01.973    2122754  1:0x0102    VOX'OS02'Ahu'Ahu15'TempSu
# 2025-11-07 07:55:07.331    2122754  1:0x0102    VOX'OS02'Ahu'Ahu15'TempSu
# 2025-11-07 07:39:03.447    2122754  1:0x0102    VOX'OS02'Ahu'Ahu15'TempSu
#
#                         equipment_name equipment_id  \
# timestamp
# 2025-12-01 12:01:17.625          Ahu15        Ahu15
# 2025-12-01 11:19:06.756          Ahu15        Ahu15
# 2025-12-01 10:37:16.069          Ahu15        Ahu15
# 2025-12-01 09:55:09.568          Ahu15        Ahu15
# 2025-12-01 09:13:17.424          Ahu15        Ahu15
# ...                                ...          ...
# 2025-11-07 08:44:33.861          Ahu15        Ahu15
# 2025-11-07 08:26:43.392          Ahu15        Ahu15
# 2025-11-07 08:11:01.973          Ahu15        Ahu15
# 2025-11-07 07:55:07.331          Ahu15        Ahu15
# 2025-11-07 07:39:03.447          Ahu15        Ahu15
#
#                                         data_received_on datapoint  \
# timestamp
# 2025-12-01 12:01:17.625 2025-12-01 12:01:17.625000+00:00  TBCMDVFD
# 2025-12-01 11:19:06.756 2025-12-01 11:19:06.756000+00:00  TBCMDVFD
# 2025-12-01 10:37:16.069 2025-12-01 10:37:16.069000+00:00  TBCMDVFD
# 2025-12-01 09:55:09.568 2025-12-01 09:55:09.568000+00:00  TBCMDVFD
# 2025-12-01 09:13:17.424 2025-12-01 09:13:17.424000+00:00  TBCMDVFD
# ...                                                  ...       ...
# 2025-11-07 08:44:33.861 2025-11-07 08:44:33.861000+00:00    TempSu
# 2025-11-07 08:26:43.392 2025-11-07 08:26:43.392000+00:00    TempSu
# 2025-11-07 08:11:01.973 2025-11-07 08:11:01.973000+00:00    TempSu
# 2025-11-07 07:55:07.331 2025-11-07 07:55:07.331000+00:00    TempSu
# 2025-11-07 07:39:03.447 2025-11-07 07:39:03.447000+00:00    TempSu
#
#                             monitoring_data service_status subsystem system_id
# timestamp
# 2025-12-01 12:01:17.625                 NaN            TBD         -         -
# 2025-12-01 11:19:06.756                 NaN            TBD         -         -
# 2025-12-01 10:37:16.069                 NaN            TBD         -         -
# 2025-12-01 09:55:09.568                 NaN            TBD         -         -
# 2025-12-01 09:13:17.424                 NaN            TBD         -         -
# ...                                     ...            ...       ...       ...
# 2025-11-07 08:44:33.861    11.9399995803833            TBD         -         -
# 2025-11-07 08:26:43.392  11.894999504089355            TBD         -         -
# 2025-11-07 08:11:01.973  11.800000190734863            TBD         -         -
# 2025-11-07 07:55:07.331  11.684999465942383            TBD         -         -
# 2025-11-07 07:39:03.447  11.569999694824219            TBD         -         -
#
# [2179853 rows x 15 columns]

# %%
ahu_df[ahu_df["point_name"]=="SpMinVFD"]

# %%
df = pd.read_csv("C:\\Users\\debas\\OneDrive\\Desktop\\bacnet_latest_data.csv")
print(f"Total records loaded: {len(df)}")

df['data_received_on'] = pd.to_datetime(df['data_received_on'], errors='coerce')

if df['data_received_on'].dt.tz is not None:
    df['timestamp'] = df['data_received_on'].dt.tz_localize(None)
else:
    df['timestamp'] = df['data_received_on']

ahu_df = df[(df["system_type"] == "AHU") & (df["equipment_id"] == "Ahu1")].copy()
print(f"AHU records: {len(ahu_df)}")

cutoff_date = pd.to_datetime("2025-11-24 10:04:16.686000")
ahu_df_filtered = ahu_df[ahu_df['timestamp'] > cutoff_date].copy()
print(f"Records after {cutoff_date}: {len(ahu_df_filtered)}")

ahu_df_filtered.head()
# Out:
# Total records loaded: 3166448
# AHU records: 114572
# Records after 2025-11-24 10:04:16.686000: 27938
# AHU records: 114572
# Records after 2025-11-24 10:04:16.686000: 27938
#              service_id   asset_code  site system_type  device_id device_ip  \
# 20921  OS01-AHU-01PIDTR  OS01-AHU-01  OS01         AHU    2122753  1:0x0101
# 20922  OS01-AHU-01PIDTR  OS01-AHU-01  OS01         AHU    2122753  1:0x0101
# 20923  OS01-AHU-01PIDTR  OS01-AHU-01  OS01         AHU    2122753  1:0x0101
# 20924  OS01-AHU-01PIDTR  OS01-AHU-01  OS01         AHU    2122753  1:0x0101
# 20925  OS01-AHU-01PIDTR  OS01-AHU-01  OS01         AHU    2122753  1:0x0101
#
#                    object_name equipment_name equipment_id  \
# 20921  VOX'OS01'Ahu'Ahu1'PIDTR           Ahu1         Ahu1
# 20922  VOX'OS01'Ahu'Ahu1'PIDTR           Ahu1         Ahu1
# 20923  VOX'OS01'Ahu'Ahu1'PIDTR           Ahu1         Ahu1
# 20924  VOX'OS01'Ahu'Ahu1'PIDTR           Ahu1         Ahu1
# 20925  VOX'OS01'Ahu'Ahu1'PIDTR           Ahu1         Ahu1
#
#                       data_received_on datapoint     monitoring_data  \
# 20921 2025-12-01 12:05:00.195000+00:00     PIDTR  0.6114294528961182
# 20922 2025-12-01 11:22:50.568000+00:00     PIDTR  56.545291900634766
# 20923 2025-12-01 10:40:54.132000+00:00     PIDTR  26.221519470214844
# 20924 2025-12-01 09:58:51.546000+00:00     PIDTR                   0
# 20925 2025-12-01 09:16:52.501000+00:00     PIDTR                   0
#
#       service_status subsystem system_id               timestamp
# 20921            TBD         -         - 2025-12-01 12:05:00.195
# 20922            TBD         -         - 2025-12-01 11:22:50.568
# 20923            TBD         -         - 2025-12-01 10:40:54.132
# 20924            TBD         -         - 2025-12-01 09:58:51.546
# 20925            TBD         -         - 2025-12-01 09:16:52.501

# %%
pivoted_df = ahu_df_filtered.pivot_table(
    index='timestamp',
    columns='datapoint',
    values='monitoring_data',
    aggfunc='first'  
).reset_index()

print(f"Pivoted data shape: {pivoted_df.shape}")
print(f"\nColumns available: {list(pivoted_df.columns)}")
print(f"\nFirst few rows:")
pivoted_df.head()
# Out:
# Pivoted data shape: (458, 51)
#
# Columns available: ['timestamp', 'AlmFAD', 'AlmFlw', 'AlmNtAuto', 'AlmPreFlt', 'AlmRACoHi', 'AlmTRHi', 'AlmTRLow', 'AlmTrpSf', 'Almbag', 'CMDSpdVFD', 'ChwTemp', 'CmdCHW', 'CmdFAD', 'CmdVFD', 'Co2Avg', 'Co2RA', 'Co2RA2', 'FbFAD', 'FbVFD', 'FireAlm', 'HuAvg1', 'HuR', 'HuR1', 'HuR2', 'HuSu', 'PIDTR', 'PIDVFD', 'RtCo2', 'SpCo2Band', 'SpCo2Hi', 'SpFAD', 'SpFAD1', 'SpHuR', 'SpHuSpcCt', 'SpMaxVFD', 'SpMinVFD', 'SpTREff', 'SpTRHiLo', 'SpTROcc', 'SpTRUnoc', 'StaAuto', 'StaFlw', 'StaVFDSf', 'TRe', 'TSOcc', 'TSu', 'TempSp1', 'TempSp2', 'TrAvg', 'TsOn']
#
# First few rows:
# datapoint               timestamp    AlmFAD    AlmFlw AlmNtAuto AlmPreFlt  \
# 0         2025-11-24 10:20:07.313  inactive  inactive  inactive  inactive
# 1         2025-11-24 10:38:51.046  inactive  inactive  inactive  inactive
# 2         2025-11-24 10:55:21.812  inactive  inactive  inactive  inactive
# 3         2025-11-24 11:12:53.997  inactive  inactive  inactive  inactive
# 4         2025-11-24 11:28:31.136  inactive  inactive  inactive  inactive
#
# datapoint AlmRACoHi   AlmTRHi  AlmTRLow  AlmTrpSf    Almbag  ... StaAuto  \
# 0          inactive  inactive  inactive  inactive  inactive  ...  active
# 1          inactive  inactive  inactive  inactive  inactive  ...  active
# 2          inactive  inactive  inactive  inactive  inactive  ...  active
# 3          inactive  inactive  inactive  inactive  inactive  ...  active
# 4          inactive  inactive  inactive  inactive  inactive  ...  active
#
# datapoint  StaFlw StaVFDSf                 TRe TSOcc                 TSu  \
# 0          active   active  23.939998626708984     1  24.350000381469727
# 1          active   active   24.07499885559082     1  24.404998779296875
# 2          active   active  24.045000076293945     1  24.389999389648438
# 3          active   active    24.0049991607666     1   24.28999900817871
# 4          active   active   23.81999969482422     1  24.229999542236328
#
# datapoint             TempSp1             TempSp2               TrAvg TsOn
# 0          22.489999771118164   20.30500030517578  21.385000228881836    1
# 1          22.514999389648438  20.584999084472656  21.544998168945312    1
# 2          22.545000076293945  20.475000381469727   21.50749969482422    1
# 3          22.619998931884766  20.494998931884766  21.564998626708984    1
# 4            22.6299991607666   20.46500015258789  21.547500610351562    1
#
# [5 rows x 51 columns]

# %%
if 'FbVFD' not in pivoted_df.columns:
    print(f"Available columns: {list(pivoted_df.columns)}")
else:
    print(f"✓ Non-null FbVFD values: {pivoted_df['FbVFD'].notna().sum()}")
    print(f"✓ Null FbVFD values: {pivoted_df['FbVFD'].isna().sum()}")
    
    print(f"\nFbVFD Statistics:")
    print(pivoted_df['FbVFD'].describe())
# Out:
# ✓ FbVFD column found
# ✓ Non-null FbVFD values: 458
# ✓ Null FbVFD values: 0
#
# FbVFD Statistics:
# count                   458
# unique                  192
# top       51.12999725341797
# freq                     21
# Name: FbVFD, dtype: object

# %%
pivoted_df["FbVFD"]
# Out:
# 0       51.15999984741211
# 1       51.13999938964844
# 2       51.18000030517578
# 3      51.119998931884766
# 4      51.189998626708984
#               ...
# 453     51.07999801635742
# 454     51.11000061035156
# 455     71.13999938964844
# 456    100.90999603271484
# 457     51.16999816894531
# Name: FbVFD, Length: 458, dtype: object

# %%
import requests
import json
from datetime import datetime
import random

def optimize_and_compare(df, target_variable="FbVFD", output_file="optimization_results.json", verbose=True):
    """
    Takes each row from df, sends to optimization endpoint, and saves results.
    
    Args:
        df: DataFrame with AHU data
        target_variable: The variable to optimize (default: "FbVFD")
        output_file: Path to save JSON results
        verbose: Show detailed error messages
    
    Returns:
        List of results with timestamp, actual, predicted, and difference
    """
    results = []
    endpoint = "http://127.0.0.1:8000/prod/generic_optimize"
    
    for idx, row in df.iterrows():
        try:
            timestamp = str(row['timestamp'])  
            
            actual_value = float(row[target_variable]) if pd.notna(row[target_variable]) else None
            
            current_conditions = {}
            for col in df.columns:
                if pd.notna(row[col]):
                    current_conditions[col] = str(row[col])
                else:
                    current_conditions[col] = "0"
            
            request_body = {
                "current_conditions": current_conditions,
                "target_variable": target_variable,
                "optimization_method": "random",
                "n_iterations": 10
            }
            
            response = requests.post(endpoint, json=request_body, timeout=30)
            
            if response.status_code == 200:
                response_data = response.json()
                predicted_value = response_data.get("best_target_value", None)
                optimized_setpoints = response_data.get("best_setpoints", {})
                
                
                current_setpoints = {}
                for setpoint_name in optimized_setpoints.keys():
                    if setpoint_name in df.columns and pd.notna(row[setpoint_name]):
                        current_setpoints[setpoint_name] = float(row[setpoint_name])
                
                if actual_value is not None and predicted_value is not None:
                    difference = actual_value - predicted_value
                else:
                    difference = None
                
                result = {
                    "timestamp": timestamp,
                    "actual_value": actual_value,
                    "predicted_value": predicted_value,
                    "difference_actual_and_pred": difference,
                    "current_setpoints": current_setpoints,
                    "optimized_setpoints": optimized_setpoints
                }
                results.append(result)
                
                print(f"✓ Processed row {len(results)}/{len(df)} - Timestamp: {timestamp}, Actual: {actual_value}, Predicted: {predicted_value}")
            else:
                error_msg = f"HTTP {response.status_code}"
                if verbose:
                    try:
                        error_detail = response.json()
                        error_msg = f"{error_msg} - {error_detail}"
                    except:
                        error_msg = f"{error_msg} - {response.text[:200]}"
                
                print(f"✗ Failed for timestamp {timestamp}: {error_msg}")
                results.append({
                    "timestamp": timestamp,
                    "actual_value": actual_value,
                    "predicted_value": None,
                    "difference_actual_and_pred": None,
                    "current_setpoints": {},
                    "optimized_setpoints": {},
                    "error": error_msg
                })
        
        except Exception as e:
            error_msg = str(e)
            if verbose:
                import traceback
                error_msg = traceback.format_exc()
            
            print(f"✗ Error processing timestamp {timestamp}: {error_msg}")
            results.append({
                "timestamp": timestamp,
                "actual_value": actual_value if 'actual_value' in locals() else None,
                "predicted_value": None,
                "difference_actual_and_pred": None,
                "current_setpoints": {},
                "optimized_setpoints": {},
                "error": error_msg
            })
    
    with open(output_file, 'w') as f:
        json.dump(results, f, indent=2)
    
    print(f"\n✓ Saved {len(results)} results to {output_file}")
    
    return results

print("Function 'optimize_and_compare()' created successfully!")
# Out:
# Function 'optimize_and_compare()' created successfully!
